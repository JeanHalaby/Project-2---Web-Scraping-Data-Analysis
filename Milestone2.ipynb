# %% [markdown]
# Jean Halaby
# Final Project Milestone #2
# 11/19/25
#
# This notebook will go over some simple data analysis of my dataset of 2024 Atlantic Divison NBA teams, which was scraped from Basketball Reference.

# %%
import pandas as pd
import numpy as np

# %%
# Import Dataset
data = pd.read_csv("nba_atlantic_2024.csv")

# %%
# Exploring Dataset
data.columns
data.shape
# Out:
# Index(['Unnamed: 0', 'G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'Team'],
#       dtype='object')

# %% [markdown]
# These just show the basic information that each column will contain and then the rows/columns of the data set.

# %%
data.dtypes
# Out:
# Unnamed: 0     object
# G             float64
# MP             object
# FG             object
# FGA            object
# FG%           float64
# 3P             object
# 3PA            object
# 3P%           float64
# 2P             object
# 2PA            object
# 2P%           float64
# FT             object
# FTA            object
# FT%           float64
# ORB            object
# DRB            object
# TRB            object
# AST            object
# STL            object
# BLK            object
# TOV            object
# PF             object
# PTS            object
# Team           object
# dtype: object

# %% [markdown]
# Showing the data types of the data set.

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     Unnamed: 0     G     MP     FG    FGA     FG%     3P    3PA     3P%  \
# 0         Team  82.0  19830   3601   7396   0.487   1351   3482   0.388
# 1       Team/G   NaN  241.8   43.9   90.2   0.487   16.5   42.5   0.388
# 2      Lg Rank   NaN      7      4      8   8.000      1      1   2.000
# 3    Year/Year   NaN  -0.8%   4.1%   1.6%   0.011   2.7%  -0.3%   0.011
# 4     Opponent  82.0  19830   3403   7515   0.453   1059   3008   0.352
# 5   Opponent/G   NaN  241.8   41.5   91.6   0.453   12.9   36.7   0.352
# 6      Lg Rank   NaN      7     13     26   2.000     15     23   4.000
# 7    Year/Year   NaN  -0.8%  -0.6%   1.6%  -0.010  11.0%   8.9%   0.007
# 8         Team  82.0  19805   3334   7307   0.456   1089   3010   0.362
# 9       Team/G   NaN  241.5   40.7   89.1   0.456   13.3   36.7   0.362
# 10     Lg Rank   NaN     10     25     16  28.000      9      9  19.000
# 11   Year/Year   NaN   0.4%  -1.9%   4.7%  -0.031   3.9%   8.6%  -0.016
# ...

# %%
data.head()
data.tail()
# Out:
#     Unnamed: 0     G     MP     FG    FGA     FG%     3P    3PA     3P%  \
# 35   Year/Year   NaN   0.0%   0.9%  -1.8%   0.013   7.0%   3.3%   0.012
# 36    Opponent  82.0  19805   3669   7476   0.491   1120   2979   0.376
# 37  Opponent/G   NaN  241.5   44.7   91.2   0.491   13.7   36.3   0.376
# 38     Lg Rank   NaN     10     28     24  26.000     26     21  24.000
# 39   Year/Year   NaN   0.0%  10.8%  10.7%   0.000  11.9%  11.3%   0.002
#
#        2P  ...     ORB   DRB    TRB    AST     STL    BLK     TOV     PF  \
# 35  -1.2%  ...  -14.6%  4.9%  -0.9%  19.1%  -17.9%  -8.5%   20.0%  -8.0%
# 36   2549  ...     919  2785   3704   2346     595    474    1137   1487
# 37   31.1  ...    11.2  34.0   45.2   28.6     7.3    5.8    13.9   18.1
# 38     26  ...      28    23     26     27      13     23      13     22
# 39  10.3%  ...   21.4%  2.8%   6.9%   9.2%   20.9%  26.1%  -16.8%  -7.3%
#
#       PTS Team
# 35  -0.4%  TOR
# 36   9741  TOR
# 37  118.8  TOR
# 38     25  TOR
# ...

# %% [markdown]
# First and last 5 rows of the dataset.

# %%
data.sample(5)
#data.info()
# Out:
#    Unnamed: 0     G     MP     FG    FGA    FG%     3P    3PA    3P%    2P  \
# 23  Year/Year   NaN  -1.1%  -1.2%  -2.8%  0.008  -3.7%  -6.0%  0.008  0.0%
# 3   Year/Year   NaN  -0.8%   4.1%   1.6%  0.011   2.7%  -0.3%  0.011  4.9%
# 17     Team/G   NaN  240.6   41.3   88.7  0.465   13.2   35.8  0.369  28.1
# 25     Team/G   NaN  241.2   41.5   89.4  0.464   12.1   33.3  0.363  29.4
# 20   Opponent  82.0  19730   3304   7026  0.470   1028   2813  0.365  2276
#
#     ...    ORB    DRB    TRB   AST    STL    BLK     TOV      PF    PTS Team
# 23  ...   1.1%  -4.8%  -3.4%  1.7%  11.3%  16.5%    3.6%   -7.6%  -4.3%  NYK
# 3   ...  10.1%   0.1%   2.2%  1.0%   6.9%  25.1%  -10.6%  -14.0%   2.2%  BOS
# 17  ...   12.7   32.5   45.2  24.4    7.5    4.1    13.2    17.6  112.8  NYK
# 25  ...   11.0   31.9   43.0  24.9    8.5    6.0    12.0    20.3  114.6  PHI
# 20  ...    839   2492   3331  2098    552    431    1082    1565   8873  NYK
#
# [5 rows x 25 columns]
